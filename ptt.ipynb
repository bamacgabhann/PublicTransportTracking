# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/bamacgabhann/PublicTransportTracking/summerschool?labpath=ptt.ipynb) <a href="https://colab.research.google.com/github/bamacgabhann/PublicTransportTracking/blob/summerschool/ptt.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code to analyse bus journeys uses the Python programming language.
#
# The point of this isn't to teach you how to code. Instead, it's to give you a taste of what is possible in data analytics.
#
# The most important thing is to try and follow what is being done in each step: you don't need to understand the code.
#
# But if you are interested in learning any of the coding, hopefully some of it will make sense, and I'll do my best to help.
#
# First, we have to import some "libraries" (code already written by other people) to help.

# %%
if 'google.colab' in str(get_ipython()):
  # !pip install osmnx movingpandas hvplot

import pandas as pd
import geopandas as gpd
import movingpandas as mpd
import matplotlib.pyplot as plt
import osmnx as ox

import hvplot.pandas

from datetime import datetime, timedelta
from shapely.geometry import Point, LineString, Polygon, box
from holoviews import opts

import warnings
warnings.filterwarnings("ignore")

plot_defaults = {"linewidth": 5, "capstyle": "round", "figsize": (10, 6), "legend": True}

# %% [markdown]
# ## Journey data
#
# In this cell, we tell the code where to find the files where we have saved the data for each journey from Strava.
#
# If you used Strava yourself, I'll show you how to use your own journey data here - we should be adding more journeys to this list. This is what I have for now:

# %%
CW1_morning_1 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW1/CW1_morning_1.gpx"
CW1_morning_2 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW1/CW1_morning_2.gpx"
CW1_morning_3 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW1/CW1_morning_3.gpx"
CW1_afternoon_1 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW1/CW1_afternoon_1.gpx"
CW1_afternoon_2 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW1/CW1_afternoon_2.gpx"
CW2_evening_1 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW2/CW2_evening_1.gpx"
CW2_evening_2 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW2/CW2_evening_2.gpx"
CW2_evening_3 = "https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPX/Carlow/CW2/CW2_evening_3.gpx"

# %% [markdown]
# ## Other data
#
# It would be useful to know where the bus stops are - luckily, I have maps of the stops for both CW1 and CW2 routes, in both directions.
#
# In this cell, we get the code to read the bus stop data, so we can add it to our maps.

# %%
CW1_north_stops = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw1_north_stops.gpkg')
CW1_south_stops = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw1_south_stops.gpkg')
CW2_east_stops = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw2_east_stops.gpkg')
CW2_west_stops = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw2_west_stops.gpkg')

# %% [markdown]
# I've also got maps showing the areas within 400m walking distance - about a 5 minute walk - from each bus stop. This cell gets the code to read that data, so we can add that to the maps if we want.

# %%
CW1_north_stops_400m = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw1_north_stops_400m.gpkg')
CW1_south_stops_400m = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw1_south_stops_400m.gpkg')
CW2_east_stops_400m = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw2_east_stops_400m.gpkg')
CW2_west_stops_400m = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/GPKG/carlow/cw2_west_stops_400m.gpkg')

# %% [markdown]
# We might want to look at who is living in various parts of Carlow. We can use data from the Irish census for that. I've already put together the data for Carlow and the surrounding area - this cell tells the code to read that data, so we can plot it on a map if we want.

# %%
carlow_census = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/census/carlow_sa.gpkg')

# %% [markdown]
# For some other things we might add, it would be useful to have a file defining the broad Carlow area, so we can look for other data within that area. This cell tells the code to read a file which has the shape of area around Carlow for which the file above has census data. It makes sense to use the same area for anything else we might want to add.

# %%
carlow_area = gpd.read_file('https://github.com/bamacgabhann/PublicTransportTracking/raw/summerschool/places/carlow_area.gpkg')

# %% [markdown]
# ## Analysing a journey
# It's time to analyse a journey! The code below already specifies one of the journeys to analyse. You can choose one of the other journeys listed above, and I'll show you how to choose your own journey data, if you used Strava yourself.

# %%
gpx = CW1_morning_2

# %% [markdown]
# Now we tell the code to read this file, and show us the data for the chosen journey.

# %%
gdf = gpd.read_file(gpx, layer="track_points").set_index("time")
gdf

# %% [markdown]
# You can see a lot of "NaN" above - there's a lot of columns with this, which means "Not a Number", meaning it has no data. We don't need all the empty columns, so the cell below tells the code to get rid of them, and show us the data we kept.

# %%
gdf.drop(
    columns=[
        "magvar",
        "geoidheight",
        "name",
        "cmt",
        "desc",
        "src",
        "link1_href",
        "link1_text",
        "link1_type",
        "link2_href",
        "link2_text",
        "link2_type",
        "sym",
        "type",
        "fix",
        "sat",
        "hdop",
        "vdop",
        "pdop",
        "ageofdgpsdata",
        "dgpsid",
    ],
    inplace=True,
)
gdf = gdf.to_crs(2157)
track = mpd.Trajectory(gdf, 1)

track.df

# %% [markdown]
# This is much tidier. You can see here that each row has a date and time on the left, and has a POINT on the right. The POINT is the coordinates of where the bus was at the date and time of that row. Since we have coordinates, we can show that on a map:

# %%
track.plot()

# %% [markdown]
# This is not a very useful map yet. One thing we can do to make it more useful is to add more data. For example, we could add some roads around Carlow. The first cell here gets the roads around Carlow from OpenStreetMap. The second cell plots a new map, showing the roads coloured according to category, with the bus journey in pink.

# %%
# create a box containing the route, expanded by 1000m, to use for extracting OpenStreetMap data
overlay_bounds = gpd.GeoDataFrame({"id":1,"geometry":[box(*gdf.total_bounds)]}).set_crs(2157)
overlay_bounds['geometry'] = overlay_bounds['geometry'].buffer(1000)
route_bounds = overlay_bounds.to_crs(4326).geometry[0]

# download the national, secondary, and local roads from OpenStreetMap in the area, cropping them to the map area
N_roads = ox.features_from_polygon(route_bounds, tags={'highway': ['trunk','trunk_link','primary','primary_link']}).to_crs(2157).overlay(overlay_bounds, how='intersection')
R_roads = ox.features_from_polygon(route_bounds, tags={'highway': ['secondary','secondary_link']}).to_crs(2157).overlay(overlay_bounds, how='intersection')
L_roads = ox.features_from_polygon(route_bounds, tags={'highway': ['tertiary','unclassified','residential','service', 'tertiary_link']}).to_crs(2157).overlay(overlay_bounds, how='intersection')

# %%
# plot
fig, ax = plt.subplots(figsize=(21, 21))

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the bus journey
track.plot(ax=ax, color='fuchsia', linewidth=4)

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# It might also be useful to see the buildings in the area - we can add those too.

# %%
# download the buildings
tags = {"building": True}
carlow_buildings = ox.features_from_polygon(route_bounds, tags)
carlow_buildings = carlow_buildings[carlow_buildings.geom_type == 'Polygon'].to_crs(2157).overlay(overlay_bounds, how='intersection')

# %%
# plot the journey with the roads and buildings
fig, ax = plt.subplots(figsize=(21, 21))

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the buildings
carlow_buildings.plot(ax=ax, color='silver')

# plot the bus journey
track.plot(ax=ax, color='fuchsia', linewidth=4)

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# It would also be useful to see where the bus stops are.
#
# This journey is on the CW1 route, travelling towards the south. The cell below specifies the bus stops on the CW1 route travelling south. If you change the journey, change this cell to specifiy the correct bus stops for the journey you're analysing.

# %%
bus_stops = CW1_south_stops

# %%
# plot the journey with the roads and buildings and bus stops
fig, ax = plt.subplots(figsize=(21, 21))

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the buildings
carlow_buildings.plot(ax=ax, color='silver')

# plot the bus journey
track.plot(ax=ax, color='fuchsia', linewidth=4, zorder=2)

# plot the bus stops
bus_stops.plot(ax=ax, marker='x', color='indigo', markersize=100, zorder=3)

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# Now our map is looking nicer, but it's still really just showing the bus route. We're not actually using the time data yet.
#
# It would be really useful to also know what distance each point was from the previous point. Plus, since we know what time the bus was at each point, if we calculate the distance we can also calculate the speed. We don't need to write complicated code for this - lucky for you, I already wrote the code to ask it to add columns for the distance from the previous point, and the speed in km/h.
#
# If you want to have some fun with this - you can always try changing the units, for example if you want the speed in miles per minute. I'm not sure why you might want that, but you can do it if you want to!

# %%
track.add_speed(name="speed (km/h)", units=("km", "h"))
track.add_distance(units="m")

track.df

# %% [markdown]
# Now we can plot the same map, but instead of showing the bus journey just as a pink line, we can colour it by what speed the bus was moving. Red for slow, green for fast, with a colour bar scale on the side.

# %%
# plot the journey with the roads and buildings and bus stops
fig, ax = plt.subplots(figsize=(21, 21))

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the buildings
carlow_buildings.plot(ax=ax, color='silver')

# plot the bus journey
track.plot(ax=ax, column='speed (km/h)', cmap='RdYlGn', vmin=0, vmax=60, linewidth=4, zorder=2)

# plot the bus stops
bus_stops.plot(ax=ax, marker='x', color='indigo', markersize=100, zorder=3)

# colourbar
sm = plt.cm.ScalarMappable(cmap='RdYlGn', norm=plt.Normalize(vmin=0, vmax=60))
cb = plt.colorbar(sm, ax=ax, extend='max', label="Speed (kph)", shrink=0.7)
cb.set_ticks([0, 10, 20, 30, 40, 50, 60])

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# Now *that* is a useful map.
#
# On that map, we have some really useful data showing how fast the bus was moving. What about when it wasn't moving?
#
# We can ask the code to identify places where the bus didn't move for some period of time. I've set this to 15 seconds, but you can change this if you like.

# %%
stopped_time = 15

# %% [markdown]
# The next cell of code identifies stationary periods of this duration or longer within a 30m diameter circle.

# %%
detector = mpd.TrajectoryStopDetector(track)
stationary_points = detector.get_stop_points(
    min_duration=timedelta(seconds=stopped_time), max_diameter=30
)

# %% [markdown]
# Let's add these points to our map:

# %%
# plot the journey with the roads and buildings and bus stops
fig, ax = plt.subplots(figsize=(21, 21))

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the buildings
carlow_buildings.plot(ax=ax, color='silver')

# plot the bus journey
track.plot(ax=ax, column='speed (km/h)', cmap='RdYlGn', vmin=0, vmax=60, linewidth=4, zorder=2)

# plot the bus stops
bus_stops.plot(ax=ax, marker='x', color='indigo', markersize=100, zorder=3)

# plot the stationary points
stationary_points.plot(ax=ax, marker='o', color='fuchsia', markersize=stationary_points['duration_s']*5)

# colourbar
sm = plt.cm.ScalarMappable(cmap='RdYlGn', norm=plt.Normalize(vmin=0, vmax=60))
cb = plt.colorbar(sm, ax=ax, extend='max', label="Speed (kph)", shrink=0.7)
cb.set_ticks([0, 10, 20, 30, 40, 50, 60])

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# We can also ask the code to give us a list of these stationary points:

# %%
stationary_points[1:]

# %% [markdown]
# And add up the total time spent stationary:

# %%
stationary_points[1:]['duration_s'].sum()

# %% [markdown]
# That's in seconds, let's show it in a more familiar way (hours:minutes:seconds):

# %%
minutes, seconds = divmod(stationary_points[1:]['duration_s'].sum(), 60)
print('0:{:02}:{:02}'.format(int(minutes), int(seconds)))

# %% [markdown]
# And compare it to the total journey time:

# %%
print(track.get_duration())

# %% [markdown]
# What percentage of the journey time was spent stationary?

# %%
timedelta(seconds=stationary_points[1:]['duration_s'].sum())/track.get_duration()*100

# %% [markdown]
# Does that seem like a lot to you?

# %% [markdown]
# We can also look at a version with the 400m walking distance zones around the bus stops shown. If you're mapping a different journey, change this to the correct set for your journey.

# %%
zones_400m = CW1_south_stops_400m

# %%
# plot the journey with the roads and buildings and bus stops and stationary points and 400m walking distance areas
fig, ax = plt.subplots(figsize=(21, 21))

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the buildings
carlow_buildings.plot(ax=ax, color='silver')

# plot the bus journey
track.plot(ax=ax, column='speed (km/h)', cmap='RdYlGn', vmin=0, vmax=60, linewidth=4, zorder=2)

# plot the bus stops
bus_stops.plot(ax=ax, marker='x', color='indigo', markersize=100, zorder=3)

# plot the 400m walking distance routes
zones_400m.plot(ax=ax, color='fuchsia', linewidth=3, zorder=1)

# plot the stationary points
stationary_points.plot(ax=ax, marker='o', color='fuchsia', markersize=stationary_points['duration_s']*5)

# colourbar
sm = plt.cm.ScalarMappable(cmap='RdYlGn', norm=plt.Normalize(vmin=0, vmax=60))
cb = plt.colorbar(sm, ax=ax, extend='max', label="Speed (kph)", shrink=0.7)
cb.set_ticks([0, 10, 20, 30, 40, 50, 60])

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# And we can also plot census data to show how many people are living in various areas - darker blue means more total people.

# %%
# plot the journey with the roads and buildings and bus stops
fig, ax = plt.subplots(figsize=(21, 21))

carlow_census.plot(ax=ax, column='T1_1AGETT', cmap='Blues', vmin=0, vmax=650, zorder=1) 

# plot all roads with a thicker black line which will show as edges,
# and a main line coloured by category
L_roads.plot(ax=ax, color='black', linewidth=1.2)
R_roads.plot(ax=ax, color='black', linewidth=1.7)
N_roads.plot(ax=ax, color='black', linewidth=2.2)
L_roads.plot(ax=ax, color='white', linewidth=1)
R_roads.plot(ax=ax, color='yellow', linewidth=1.5)
N_roads.plot(ax=ax, color='green', linewidth=2)

# plot the buildings
carlow_buildings.plot(ax=ax, color='silver')

# plot the bus journey
track.plot(ax=ax, column='speed (km/h)', cmap='RdYlGn', vmin=0, vmax=60, linewidth=4, zorder=2)

# plot the bus stops
bus_stops.plot(ax=ax, marker='x', color='indigo', markersize=100, zorder=3)

# plot the 400m walking distance routes
zones_400m.plot(ax=ax, color='fuchsia', linewidth=3, zorder=1)

# plot the stationary points
stationary_points.plot(ax=ax, marker='o', color='fuchsia', markersize=stationary_points['duration_s']*5)

# colourbar
sm = plt.cm.ScalarMappable(cmap='RdYlGn', norm=plt.Normalize(vmin=0, vmax=60))
cb = plt.colorbar(sm, ax=ax, extend='max', label="Speed (kph)", shrink=0.7)
cb.set_ticks([0, 10, 20, 30, 40, 50, 60])

ax.set_xlim(670000, 676000)
ax.set_ylim(673500, 680000)

plt.show()

# %% [markdown]
# There's a lot more census data than just the total number of people - if you're interested in looking at what else might be in there, I'd be happy to show you.

# %% [markdown]
# ## Interactive maps
#
# So we have produced a nice map, but you know what would be great? If we could zoom and scroll. Well, we can.

# %%
opts.defaults(opts.Overlay(active_tools=["wheel_zoom"], frame_width=800, frame_height=600))

journey_plot = track.to_crs(4326).hvplot(
    c="speed (km/h)",
    clim=(0, 60),
    line_width=7.0,
    x="Longitude",
    y="Latitude",
    xlabel="Longitude",
    ylabel="Latitude",
    clabel="Speed (km/h)",
    tiles="CartoLight",
    cmap="RdYlGn",
    colorbar=True,
)

stationary_plot = stationary_points.set_crs(2157).to_crs(4326).hvplot(
    geo=True, size="duration_s", color="deeppink"
)

bus_stops_plot = bus_stops.to_crs(4326).hvplot(
    geo=True, size=40, marker="+", color="blue"
)

track_plot = (
    journey_plot * stationary_plot * bus_stops_plot
)

track_plot

# %% [markdown]
# You can zoom and scroll on this map, and you can use the save icon if you want to save the map image. The size can be adjusted in the top cell (adjust frame_width=800, frame_height=600)

# %% [markdown]
# Now, try another journey. How does it compare?
